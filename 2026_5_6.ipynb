# %% [markdown]
# ##画像データの処理

# %%
import os
print(os.getcwd())
from PIL import Image
sample = Image.open('tiger.png')
# Out:
# c:\Users\shige\OneDrive\programming\python_practice

# %%
print(type(sample))
sample
# Out:
# <class 'PIL.PngImagePlugin.PngImageFile'>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=660x700>
